# %%
# !uv add pandas

# %%
import pandas as pd

# %%
fname="/home/ins/AIOps-SRE-agent/data/non_HTTP_error.csv"
df = pd.read_csv(fname)
df.head(1)
# Out:
#                     @timestamp  @version  @version.keyword  \
# 0  Feb 25, 2026 @ 09:54:00.000         1                 1
#
#                     _id                                           _ignored  \
# 0  Nvm3kpwBX9glp_byzfVA  event.original.keyword, log_message.keyword, m...
#
#                          _index _score           app_name   app_name.keyword  \
# 0  kem-be-asrama-stg-2026.02.25      -  kem-be-asrama-stg  kem-be-asrama-stg
#
#   environment  ...                                        log_message  \
# 0     staging  ...  The resource owner or authorization server den...
#
#                                  log_message.keyword  \
# 0  The resource owner or authorization server den...
#
#                                              message  \
# 0  [2026-02-25 09:54:00] local.ERROR: The resourc...
#
#                                      message.keyword        namespace  \
# 0  [2026-02-25 09:54:00] local.ERROR: The resourc...  student-affairs
#
# ...

# %%
len(df)
# Out:
# 352

# %%
df.columns
# Out:
# Index(['@timestamp', '@version', '@version.keyword', '_id', '_ignored',
#        '_index', '_score', 'app_name', 'app_name.keyword', 'environment',
#        'environment.keyword', 'event.original', 'event.original.keyword',
#        'laravel_env', 'laravel_env.keyword', 'log_message',
#        'log_message.keyword', 'message', 'message.keyword', 'namespace',
#        'namespace.keyword', 'severity', 'severity.keyword', 'source_type',
#        'source_type.keyword'],
#       dtype='str')

# %%
df_e = df[['message']]
df_e['message'][300]
# Out:
# '[2026-02-24 15:14:44] local.ERROR: The resource owner or authorization server denied the request. {"exception":"[object] (League\\\\OAuth2\\\\Server\\\\Exception\\\\OAuthServerException(code: 9): The resource owner or authorization server denied the request. at /usr/share/nginx/html/vendor/league/oauth2-server/src/Exception/OAuthServerException.php:243)'
